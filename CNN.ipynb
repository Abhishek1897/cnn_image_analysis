# %%
# Import necessary libraries
from keras.datasets import cifar10
import matplotlib.pyplot as plt

# Load the CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ...
# 170498071/170498071 [==============================] - 30s 0us/step

# %% [markdown]
# # Data Exploration:

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    plt.xlabel(y_train[i])
plt.show()

print("Training set shape (images, height, width, channels):", X_train.shape)
print("Training set shape (labels):", y_train.shape)
print("Test set shape (images, height, width, channels):", X_test.shape)
print("Test set shape (labels):", y_test.shape)
# Out:
# C:\Users\abhis\anaconda3\Lib\site-packages\matplotlib\text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Training set shape (images, height, width, channels): (50000, 32, 32, 3)
# Training set shape (labels): (50000, 1)
# Test set shape (images, height, width, channels): (10000, 32, 32, 3)
# Test set shape (labels): (10000, 1)

# %%
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np

(X_train, y_train), (X_test, y_test) = cifar10.load_data()


label_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']


def plot_images(images, labels, nrows, ncols):
    plt.figure(figsize=(10, 10))
    for i in range(nrows * ncols):
        plt.subplot(nrows, ncols, i+1)
        plt.imshow(images[i])
        plt.title(label_names[labels[i][0]])
        plt.axis('off')
    plt.show()


plot_images(X_train, y_train, 2, 5)

# %% [markdown]
# # Preprocessing:

# %%
import tensorflow as tf
from keras.utils import to_categorical

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print('Image data normalized and labels one-hot encoded.')
# Out:
# Image data normalized and labels one-hot encoded.

# %% [markdown]
# # Model Building:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN architecture designed successfully.')
# Out:
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# CNN architecture designed successfully.

# %% [markdown]
# # Model Compilation:

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print('Model compiled successfully.')
# Out:
# Model compiled successfully.

# %% [markdown]
# # Training:

# %%
batch_sizes = [32, 64, 128]
epochs = [10, 20, 30]

for batch_size in batch_sizes:
    for epoch in epochs:
        print(f"Training with batch size: {batch_size}, epochs: {epoch}")
        
        
        history = model.fit(X_train, y_train, epochs=epoch, batch_size=batch_size, validation_data=(X_test, y_test))
        
    
        test_loss, test_acc = model.evaluate(X_test, y_test)
        print(f'Test Loss: {test_loss}, Test Accuracy: {test_acc}')
        
        # Plot training and validation accuracy
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title(f'Training with batch size: {batch_size}, epochs: {epoch}')
        plt.legend()
        plt.show()
# Out:
# Training with batch size: 32, epochs: 10
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.5380 - accuracy: 0.4372 - val_loss: 1.1894 - val_accuracy: 0.5752
# Epoch 2/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.1443 - accuracy: 0.5953 - val_loss: 1.0293 - val_accuracy: 0.6318
# Epoch 3/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9786 - accuracy: 0.6581 - val_loss: 0.9198 - val_accuracy: 0.6765
# Epoch 4/10
# ...

# %% [markdown]
# # Evaluation:

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 3.3927 - accuracy: 0.7334
# Test Loss: 3.392728090286255
# Test Accuracy: 0.7333999872207642

# %% [markdown]
# # Analysis:
#
# Training with batch size: 32
# Epochs: 10
#
# Test Loss: 0.8628
# Test Accuracy: 0.7211
#
# Epochs: 20
#
# Test Loss: 1.2733
# Test Accuracy: 0.7357
#
# Epochs: 30
#
# Test Loss: 1.6916
# Test Accuracy: 0.7259
#
# Training with batch size: 64
#
# Epochs: 10
#
# Test Loss: 1.9524
# Test Accuracy: 0.7345
#
# Epochs: 20
#
# Test Loss: 2.3964
# Test Accuracy: 0.7372
#
# Epochs: 30
#
# Test Loss: 2.6313
# Test Accuracy: 0.7351
#
# The training was conducted on the MNIST fashion dataset using different batch sizes (32 and 64) and epochs (10, 20, and 30). Across all experiments, the test accuracy increased with the number of epochs for both batch sizes. However, there was a slight variation in the test loss and accuracy between different batch sizes. For batch size 32, the test accuracy improved from 0.7211 to 0.7259 as the number of epochs increased from 10 to 30, while the test loss increased from 0.8628 to 1.6916. Similarly, for batch size 64, the test accuracy improved from 0.7345 to 0.7351, and the test loss increased from 1.9524 to 2.6313 over the same epochs. Despite some fluctuations, the overall trend shows an increase in accuracy with the number of epochs, with batch size 64 exhibiting slightly better performance in terms of test accuracy.
